# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import seaborn as sns

from keras.layers import Dense, BatchNormalization, Dropout, LSTM, Input,BatchNormalization, LeakyReLU
from keras.optimizers import RMSprop,SGD,Adam
from keras.regularizers import l2
from keras import regularizers
from keras import callbacks
from keras.models import Sequential
from keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
from keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## IMPORTING DATASET

# %%
data = pd.read_csv("DATASET/Medicaldataset.csv")
data.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   63       1          66                      160                        83
# 1   20       1          94                       98                        46
# 2   56       1          64                      160                        77
# 3   66       1          70                      120                        55
# 4   54       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %% [markdown]
# ## EDA

# %%
cols= ["#6daa9f","#774571"]
fig_1=sns.countplot(x= data["Result"], palette= cols)

plt.savefig("Fig_1.png", format="png", dpi=300, bbox_inches="tight")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19864\3649692763.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   fig_1=sns.countplot(x= data["Result"], palette= cols)

# %%
# change result to numerical valueab

data['Result'] = data['Result'].map({'negative': 0, 'positive': 1})

data.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   63       1          66                      160                        83
# 1   20       1          94                       98                        46
# 2   56       1          64                      160                        77
# 3   66       1          70                      120                        55
# 4   54       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin  Result
# 0        160.0   1.80     0.012       0
# 1        296.0   6.75     1.060       1
# 2        270.0   1.99     0.003       0
# 3        270.0  13.87     0.122       1
# 4        300.0   1.08     0.003       0

# %% [markdown]
# ### CORRELATION MATRIX

# %%
cmap = sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

plt.savefig("Fig_2.png", format="png", dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(20,12))
Days_of_week=sns.countplot(x=data['Age'],data=data, hue ="Result",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")

plt.savefig("Fig_3.png", format="png", dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(20,12))
Days_of_week=sns.countplot(x=data['Gender'],data=data, hue ="Result",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")

plt.savefig("Fig_4.png", format="png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## DATA PRE PROCESSING

# %%
# split data into feautures and labels
Feature=data.drop(["Result"],axis=1)
Label=data["Result"]

Feature.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   63       1          66                      160                        83
# 1   20       1          94                       98                        46
# 2   56       1          64                      160                        77
# 3   66       1          70                      120                        55
# 4   54       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin
# 0        160.0   1.80     0.012
# 1        296.0   6.75     1.060
# 2        270.0   1.99     0.003
# 3        270.0  13.87     0.122
# 4        300.0   1.08     0.003

# %%
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = Feature,palette = colours)
plt.xticks(rotation=90)
plt.savefig("Fig_5.png", format="png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19864\1495474496.py:3: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.boxenplot(data = Feature,palette = colours)

# %% [markdown]
# #### NORMALIZATION

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Feature = scaler.fit_transform(Feature)

# %% [markdown]
# #### AFTER NORMALIZATION

# %%
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = Feature,palette = colours)
plt.xticks(rotation=90)
plt.savefig("Fig_8.png", format="png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19864\3050237779.py:3: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.boxenplot(data = Feature,palette = colours)

# %% [markdown]
# #### SPLIT DATA

# %%
# split data into testing and training data
Feature_train, Feature_test, Label_train,Label_test = train_test_split(Feature,Label,test_size=0.25,random_state=7)

# %% [markdown]
# ## BUILDING MODEL

# %%
# EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=15, 
    min_delta=0.0001, 
    restore_best_weights=True
)

# ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=5, 
    min_lr=1e-6
)

#ANN model architecture
model = Sequential()
model.add(Input(shape=(Feature_train.shape[1],)))  # Input layer for the number of features
model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU(negative_slope=0.1))
model.add(Dropout(0.2))

model.add(Dense(16, kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU(negative_slope=0.1))
model.add(Dropout(0.2))

model.add(Dense(8, kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU(negative_slope=0.1))
model.add(Dropout(0.3))

model.add(Dense(1, kernel_initializer='glorot_uniform', activation='sigmoid'))

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001), 
    loss='binary_crossentropy', 
    metrics=['accuracy']
)

# Model summary
model.summary()
# Out:
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_100 (Dense)               │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_71          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_75 (LeakyReLU)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_73 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_101 (Dense)               │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_72          │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_76 (LeakyReLU)      │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_74 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_102 (Dense)               │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_73          │ (None, 8)              │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_77 (LeakyReLU)      │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_75 (Dropout)            │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_103 (Dense)               │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,185 (4.63 KB)
#  Trainable params: 1,073 (4.19 KB)
#  Non-trainable params: 112 (448.00 B)

# %% [markdown]
# ### TRAINING MODEL

# %%
history = model.fit(
    Feature_train, 
    Label_train, 
    validation_split=0.2,
    epochs=100, 
    batch_size=64, 
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.4985 - loss: 1.8519 - val_accuracy: 0.5051 - val_loss: 1.7617 - learning_rate: 0.0010
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5620 - loss: 1.7567 - val_accuracy: 0.5455 - val_loss: 1.6872 - learning_rate: 0.0010
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5502 - loss: 1.6936 - val_accuracy: 0.5859 - val_loss: 1.6315 - learning_rate: 0.0010
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5851 - loss: 1.6472 - val_accuracy: 0.5859 - val_loss: 1.5850 - learning_rate: 0.0010
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6050 - loss: 1.5927 - val_accuracy: 0.6061 - val_loss: 1.5441 - learning_rate: 0.0010
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5893 - loss: 1.5738 - val_accuracy: 0.6515 - val_loss: 1.5054 - learning_rate: 0.0010
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6271 - loss: 1.5138 - val_accuracy: 0.6566 - val_loss: 1.4700 - learning_rate: 0.0010
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6422 - loss: 1.4688 - val_accuracy: 0.6869 - val_loss: 1.4369 - learning_rate: 0.0010
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6130 - loss: 1.4425 - val_accuracy: 0.6818 - val_loss: 1.4047 - learning_rate: 0.0010
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6472 - loss: 1.4107 - val_accuracy: 0.6717 - val_loss: 1.3744 - learning_rate: 0.0010
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6206 - loss: 1.3736 - val_accuracy: 0.6616 - val_loss: 1.3450 - learning_rate: 0.0010
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6426 - loss: 1.3233 - val_accuracy: 0.6515 - val_loss: 1.3166 - learning_rate: 0.0010
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6236 - loss: 1.3081 - val_accuracy: 0.6465 - val_loss: 1.2895 - learning_rate: 0.0010
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6457 - loss: 1.2806 - val_accuracy: 0.6465 - val_loss: 1.2645 - learning_rate: 0.0010
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6615 - loss: 1.2385 - val_accuracy: 0.6364 - val_loss: 1.2392 - learning_rate: 0.0010
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6639 - loss: 1.2223 - val_accuracy: 0.6364 - val_loss: 1.2149 - learning_rate: 0.0010
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6745 - loss: 1.1807 - val_accuracy: 0.6313 - val_loss: 1.1921 - learning_rate: 0.0010
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6645 - loss: 1.1643 - val_accuracy: 0.6313 - val_loss: 1.1700 - learning_rate: 0.0010
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6661 - loss: 1.1509 - val_accuracy: 0.6364 - val_loss: 1.1487 - learning_rate: 0.0010
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6580 - loss: 1.1199 - val_accuracy: 0.6465 - val_loss: 1.1282 - learning_rate: 0.0010
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6606 - loss: 1.1046 - val_accuracy: 0.6566 - val_loss: 1.1088 - learning_rate: 0.0010
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6813 - loss: 1.0847 - val_accuracy: 0.6566 - val_loss: 1.0899 - learning_rate: 0.0010
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7250 - loss: 1.0387 - val_accuracy: 0.6566 - val_loss: 1.0710 - learning_rate: 0.0010
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6838 - loss: 1.0335 - val_accuracy: 0.6465 - val_loss: 1.0536 - learning_rate: 0.0010
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6814 - loss: 1.0051 - val_accuracy: 0.6414 - val_loss: 1.0366 - learning_rate: 0.0010
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6741 - loss: 0.9939 - val_accuracy: 0.6515 - val_loss: 1.0202 - learning_rate: 0.0010
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6879 - loss: 0.9690 - val_accuracy: 0.6566 - val_loss: 1.0039 - learning_rate: 0.0010
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7674 - loss: 0.5160 - val_accuracy: 0.7475 - val_loss: 0.5770 - learning_rate: 5.0000e-04
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7814 - loss: 0.5173 - val_accuracy: 0.7525 - val_loss: 0.5720 - learning_rate: 5.0000e-04
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7686 - loss: 0.5171 - val_accuracy: 0.7677 - val_loss: 0.5696 - learning_rate: 5.0000e-04
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7347 - loss: 0.5386 - val_accuracy: 0.7828 - val_loss: 0.5637 - learning_rate: 5.0000e-04
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7221 - loss: 0.5267 - val_accuracy: 0.7879 - val_loss: 0.5598 - learning_rate: 5.0000e-04
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7652 - loss: 0.5176 - val_accuracy: 0.7828 - val_loss: 0.5622 - learning_rate: 5.0000e-04
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7514 - loss: 0.5177 - val_accuracy: 0.7879 - val_loss: 0.5615 - learning_rate: 5.0000e-04
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7242 - loss: 0.5433 - val_accuracy: 0.7879 - val_loss: 0.5608 - learning_rate: 5.0000e-04
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7479 - loss: 0.5403 - val_accuracy: 0.7828 - val_loss: 0.5612 - learning_rate: 5.0000e-04
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7546 - loss: 0.5170 - val_accuracy: 0.7879 - val_loss: 0.5587 - learning_rate: 5.0000e-04
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7820 - loss: 0.5063 - val_accuracy: 0.7828 - val_loss: 0.5563 - learning_rate: 5.0000e-04
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7524 - loss: 0.5112 - val_accuracy: 0.7828 - val_loss: 0.5502 - learning_rate: 5.0000e-04
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7402 - loss: 0.5315 - val_accuracy: 0.7879 - val_loss: 0.5507 - learning_rate: 5.0000e-04
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7968 - loss: 0.4784 - val_accuracy: 0.7677 - val_loss: 0.5498 - learning_rate: 5.0000e-04
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7628 - loss: 0.4951 - val_accuracy: 0.7727 - val_loss: 0.5526 - learning_rate: 5.0000e-04
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7472 - loss: 0.5032 - val_accuracy: 0.7727 - val_loss: 0.5515 - learning_rate: 5.0000e-04

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.savefig("Fig_6.png", format="png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### MODEL PERFORMANCE

# %%
y_pred = model.predict(Feature_test)
y_pred = ( y_pred> 0.5)
np.set_printoptions()
#y_pred
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
ann_cm=confusion_matrix(Label_test,y_pred)
ann_ac=accuracy_score(y_pred,Label_test)
plt.title("confusion_matrix")
sns.heatmap(ann_cm,cmap = cmap1,annot=True,fmt="d",cbar=False)
print('Model_accuracy:',ann_ac)

plt.savefig("Fig_7.png", format="png", dpi=300, bbox_inches="tight")
# Out:
# Model_accuracy: 0.8393939393939394

# %%
print(classification_report(Label_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79       123
#            1       0.87      0.87      0.87       207
#
#     accuracy                           0.84       330
#    macro avg       0.83      0.83      0.83       330
# weighted avg       0.84      0.84      0.84       330

# %% [markdown]
# ## EXPORT TRAINED MODEL

# %%
import pickle
pickle.dump(model,open('My_ANN.pkl','wb'))

# %% [markdown]
# ### TESTING PICKLED MODEL

# %%
test=Feature_test.iloc[7]
test = np.array(test, dtype=np.float32).reshape(1, 8)

# %%
model_1 = pickle.load(open('My_ANN.pkl','rb'))
Prediction = model_1.predict([[test]])

# %%
Prediction = (Prediction > 0.5)
Prediction
